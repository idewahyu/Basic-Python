# %% [markdown]
# #Dynamic Typing
# Python is known as one of the languages that implement dynamic typing, which means the Python interpreter does type checking only as code runs, and the type of a variable is allowed to change over its lifetime. Here a couple of dynamic typing examples:

# %% [markdown]
# - type()
#
#   Type() is one of the Python's built-in functions that helps you find the class type of the variable given as input.

# %%
a = 100
type(a)
# Out:
# int

# %% [markdown]
# - len()
#
#  The second function of Python’s built-in functions is len(). It returns the length of an object. For example, it can return the number of items in a list. You can use the function with many different data types. However, not all data types are valid arguments for len().

# %%
a = "Data"
len(a)
# Out:
# 4

# %%
b = 10
len(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-9dd228f947b9> in <module>()
#       1 b = 10
# ----> 2 len(b)
#
# TypeError: object of type 'int' has no len()
