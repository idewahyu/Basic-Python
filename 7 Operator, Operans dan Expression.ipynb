# %% [markdown]
# Addiction

# %%
1 + 4
# Out:
# 5

# %% [markdown]
# Subtraction

# %%
1000 - 7
# Out:
# 993

# %% [markdown]
# Multiplication

# %%
3 * 12
# Out:
# 36

# %% [markdown]
# String Multiplication

# %%
'ora' * 5
# Out:
# 'oraoraoraoraora'

# %% [markdown]
# Division

# %%
45/9
# Out:
# 5.0

# %%
22/7

# python has a limitation in displaying numbers so it will stop at 16 numbers so that phi should not stop showing only 16 numbers
# Out:
# 3.142857142857143

# %% [markdown]
# Exponentiation

# %%
4**6
# Out:
# 4096

# %% [markdown]
# Root
#
# in python use root using the power of number power divided by a decimal number

# %%
9**0.5
# Out:
# 3.0

# %% [markdown]
# Floor Division

# %%
7//3
# Out:
# 2

# %% [markdown]
# Modulo

# %%
7%3
# Out:
# 1

# %% [markdown]
# Less than and less than aequal to

# %%
2 < 4
# Out:
# True

# %%
4 <= 3
# Out:
# False

# %% [markdown]
# More than and more than equal

# %%
35 > 4
# Out:
# True

# %%
35 >= 34
# Out:
# True

# %% [markdown]
# Equal to

# %%
4 == 5

# if equal should be '==' otherwise '=' will be treated as input variable so no output boolean will be returned
# Out:
# False

# %%
3 == 3
# Out:
# True

# %% [markdown]
# Not Equal to

# %%
3 != 3
# Out:
# False

# %%
3 !=4
# Out:
# True

# %% [markdown]
# You can use string too in function

# %%
a = 'Keynes'

# %%
b = ' keynes'

# %%
a == b

# different capital letters can make a difference to the function
# Out:
# False

# %% [markdown]
# #Boolean Not
#
# - if x is true, the function will return false
# - if x evaluates to false, the function returns true

# %%
x = False

# %%
not x
# Out:
# True

# %% [markdown]
# #and (Boolean AND )
#
# x and y will return false if x is false, or the function will return y

# %%
a = True

# %%
b = False

# %%
a and b
# Out:
# False

# %%
a = True

# %%
b = True

# %%
a and b
# Out:
# True

# %% [markdown]
# #or  (Boolean OR)
#
# if x is true then the function will return true or the function will return the value of y

# %%
a = True

# %%
b = False

# %%
a or b
# Out:
# True

# %%
a = False

# %%
b = False

# %%
a or b
# Out:
# False

# %% [markdown]
# #short way to write expression

# %%
a = 2

# %%
a = a * 3

# %%
# or you can write  in this way 

a*=3

# %%
print (a)
# Out:
# 18

# %%
# and can also apply to other operations

a -= 10

# %%
print (a)
# Out:
# 8

# %%
# python has been able to sort the order of operations without the need to separate them with brackets but the use of brackets is needed for ease of reading

1 + 2 *5 + 4 - 2 /4 *2 +1 **2
# Out:
# 15.0

# %%
1 + (2*5) + 4 - ((2/4)*2)+ (1**2)
# Out:
# 15.0
