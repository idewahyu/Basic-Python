# %%
Nama=input("Nama : ")
print("Nama : {}".format(Nama))
print("Nama : %s"%(Nama))
print("Nama :",Nama)
# Out:
# Nama : Devanaga Saputra
# Nama : Devanaga Saputra
# Nama : Devanaga Saputra
# Nama : Devanaga Saputra

# %%
D=" Devanaga Saputra "

# %%
D.rstrip()
# Out:
# ' Devanaga Saputra'

# %%
D.lstrip()
# Out:
# 'Devanaga Saputra '

# %%
D.strip()
# Out:
# 'Devanaga Saputra'

# %%
a="Deva Sa"
print(a.startswith("Deva"))
print(a.endswith("Sa"))
b="Love You Data Engineer"
print(b.startswith("Engineer"))
print(b.endswith("Engineer"))
# Out:
# True
# True
# False
# True

# %%
c="Aku Cinta Kamu"
print(c.replace("Cinta","Benci"))
e="Excel Cahaya Asia, Excel Pelindung Asia, Excel Pemimpin Asia"
print(e.replace("Excel","Jepang",3))
# Out:
# Aku Benci Kamu
# Jepang Cahaya Asia, Jepang Pelindung Asia, Jepang Pemimpin Asia

# %%
g="aku seorang kapiten 212 mempunyai pedang panjang"
print(g.isupper())
print(g.islower())
print(g.isalpha())
print(g.isalnum())
print(g.isdecimal())
print(g.isspace())
print(g.istitle())
print(g.upper().lower().islower())
print(g.lower().upper().isupper())
# Out:
# False
# True
# False
# False
# False
# False
# False
# True
# True

# %%
a=7
print(str(a).zfill(3))
b="Aku"
print(b.zfill(5))
c="Alumni212"
print(c.zfill(14))
d=212
print(str(d).zfill(5))
# Out:
# 007
# 00Aku
# 00000Alumni212
# 00212

# %%
Nasional="Hiduplah Indonesia Raya"
print("Indonesia" in Nasional)
print("Raya" not in Nasional)
# Out:
# True
# False
